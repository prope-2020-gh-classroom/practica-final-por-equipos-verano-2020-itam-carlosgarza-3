# %% [markdown]
# # Análisis Estadístico.
#
# En el notebook pasado realicé toda la limpieza y preparación de los datos. En este notebook lo que haré será describir los datos mes a mes y luego realizar un breve reporte del cuatrimestre.

# %%
library(ggplot2)
library(tidyverse)

# %%
data <- read.csv('cuarto_cuatrimestre.csv')
head(data)
# Out:
#   X lpep_pickup_datetime lpep_dropoff_datetime passenger_count trip_distance
# 1 1 2019-09-01 00:10:53  2019-09-01 00:23:46   5               2.00
# 2 2 2019-09-01 00:27:06  2019-09-01 00:33:22   1               1.73
# 3 3 2019-09-01 00:43:23  2019-09-01 00:59:54   1               3.42
# 4 4 2019-09-01 00:28:55  2019-09-01 00:52:09   1               4.34
# 5 5 2019-09-01 00:13:37  2019-09-01 00:26:46   1               3.59
# 6 6 2019-09-01 00:35:43  2019-09-01 00:47:21   1               2.10
#   fare_amount tip_amount total_amount payment_type trip_type trip_duration
# 1 10.5        2.36       14.16        1            1         0.2147222
# 2  7.5        1.50       10.30        1            1         0.1044444
# 3 14.0        3.06       18.36        1            1         0.2752778
# 4 18.0        3.86       23.16        1            1         0.3872222
# 5 13.0        5.12       22.17        1            1         0.2191667
# ...

# %%
#la columna de 'X' se generó sola al convertir el archivo a un csv. 
data$X <- NULL

# %% [markdown]
# ## Análisis Exploratorio de algunas variables.
#
# Utilizaré el mes de septiembre para descubrir qué tipos de gráficas y análisis se puede realizar y usar menos poder de cómputo en el proceso. Después realizaré el análisis relevante para todo el dataframe.

# %%
sept <- data[data$month=='Septiembre',]

# %%
head(sept)
# Out:
#   lpep_pickup_datetime lpep_dropoff_datetime passenger_count trip_distance
# 1 2019-09-01 00:10:53  2019-09-01 00:23:46   5               2.00
# 2 2019-09-01 00:27:06  2019-09-01 00:33:22   1               1.73
# 3 2019-09-01 00:43:23  2019-09-01 00:59:54   1               3.42
# 4 2019-09-01 00:28:55  2019-09-01 00:52:09   1               4.34
# 5 2019-09-01 00:13:37  2019-09-01 00:26:46   1               3.59
# 6 2019-09-01 00:35:43  2019-09-01 00:47:21   1               2.10
#   fare_amount tip_amount total_amount payment_type trip_type trip_duration
# 1 10.5        2.36       14.16        1            1         0.2147222
# 2  7.5        1.50       10.30        1            1         0.1044444
# 3 14.0        3.06       18.36        1            1         0.2752778
# 4 18.0        3.86       23.16        1            1         0.3872222
# 5 13.0        5.12       22.17        1            1         0.2191667
# 6  9.5        1.70       13.00        1            1         0.1938889
# ...

# %%
dim(sept)
# Out:
# [1] 156419     12

# %% [markdown]
# ####  Número de pasajeros.
#
# Los neoyorquinos viajan solos, en general.

# %%
mean(sept$passenger_count)
# Out:
# [1] 1.321093

# %%
plot(table(sept$passenger_count))
# Out:
# plot without title

# %% [markdown]
# #### Trip Distance
#
# ¿Cuántas millas recorren en general los neoyorquinos por viaje?

# %%
mean(sept$trip_distance)
# Out:
# [1] 3.105578

# %% [markdown]
# Son como 5 km por viaje —no es mucho.

# %%
boxplot(sept$trip_distance)
# Out:
# plot without title

# %%
summary(sept$trip_distance)
#algunos pillas se van 68 millas. Definitivamente un outlier
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   0.000   1.180   2.020   3.106   3.750  68.410

# %% [markdown]
# Veamos más variables

# %%
summary(sept$fare_amount)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.06    7.00   10.00   13.37   16.00  400.00

# %%
summary(sept$total_amount)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    2.76    9.96   14.46   18.50   22.05  480.00

# %%
summary(sept$trip_duration)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.0000  0.1189  0.1931  0.2394  0.3069  4.9814

# %%
boxplot(sept$trip_duration)
# Out:
# plot without title

# %%
plot(table(sept$payment_type))
#1 es tarjeta y 2 es efectivo
# Out:
# plot without title

# %%
plot(sept$trip_distance, sept$total_amount)
# Out:
# plot without title

# %%
#dejará más propina la gente que viaja más?
plot(sept$trip_distance, sept$tip_amount)
# Out:
# plot without title

# %% [markdown]
# ## Análisis del cuatrimestre.
